# %%
from skimage.io import imread
import pyclesperanto_prototype as cle
import dask.array as da
import napari

filename = r"C:\Users\ryans\OneDrive\Documents\Bia POL stuff\Napari Plugin Development\2d timelapse example data.svg\2d+t CalibZAPWfixed.tif"
original_image = imread(filename)

viewer = napari.Viewer()
image_layer = viewer.add_image(original_image)

napari.utils.nbscreenshot(viewer)
# Out:
# C:\Users\ryans\Anaconda3\envs\np_workflows_v1\lib\site-packages\napari_tools_menu\__init__.py:165: FutureWarning: Public access to Window.qt_viewer is deprecated and will be removed in
# v0.5.0. It is considered an "implementation detail" of the napari
# application, not part of the napari viewer model. If your use case
# requires access to qt_viewer, please open an issue to discuss.
#   self.tools_menu = ToolsMenu(self, self.qt_viewer.viewer)

# %%
from napari.types import ImageData
from skimage.filters import gaussian
from napari_time_slicer import time_slicer_dask
import pyclesperanto_prototype as cle
@time_slicer_dask
def skimage_gaussian(image: ImageData, sigma: int = 2, viewer: napari.Viewer = None) -> ImageData:
    print('called')
    return gaussian(image, sigma=sigma)

returned = skimage_gaussian(image_layer.data, sigma = 4,viewer = viewer)
cle.imshow(returned[99])
# Out:
# called
# called

# %%
cle.imshow(returned[1])
# Out:
# called

# %%
import magicgui

widget = magicgui.magicgui(skimage_gaussian)
viewer.window.add_dock_widget(widget,autocall = True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14584/3056270535.py in <module>
#       2
#       3 widget = magicgui.magicgui(skimage_gaussian)
# ----> 4 viewer.window.add_dock_widget(widget,autocall = True)
#
# TypeError: add_dock_widget() got an unexpected keyword argument 'autocall'

# %%
viewer.dims.nsteps[0]
# Out:
# 100

# %%
viewer.dims.current_step[0]
# Out:
# 50
